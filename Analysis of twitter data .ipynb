# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt  
import seaborn as sns 

# %matplotlib inline

# %%
df  = pd.read_csv(r"C:\Users\HP\Documents\Documents\Data project\Twitter web scrapping\twitter_scrapper\twitter_data.csv")

# %%
df
# Out:
#                 tweet_id         username                           name  \
# 0    1691623868409004062   porterfieldlol              ts'ǫǫ̀kołı̨ı̨ ✨
# 1    1691945051574993282   porterfieldlol              ts'ǫǫ̀kołı̨ı̨ ✨
# 2    1691612322496737746   OurYellowknife            City of Yellowknife
# 3    1691913973527134239   weathernetwork            The Weather Network
# 4    1691633128434028992          NWTFire                       NWT Fire
# ..                   ...              ...                            ...
# 438  1702042973951668628      Melissa_Lem                Dr. Melissa Lem
# 439  1702044083286397074   eyeonthearctic             RCI-EyeOnTheArctic
# 440  1702215241457967315  Theresa70948126               Theresa Robinson
# 441  1702362826260750342         CBCbrief  CBCbrief - CBC News headlines
# 442  1702675827521917337       CabinRadio                    Cabin Radio
#
#                       creation_date  \
# 0    Wed Aug 16 01:32:13 +0000 2023
# ...

# %%
df.tail(10)
# Out:
#                 tweet_id         username  \
# 433  1701981563876208740          CBCNews
# 434  1701971640299536825   Bballshoeguide
# 435  1702075940015108205   weathernetwork
# 436  1701977789795340424         CBCbrief
# 437  1701752552855867429        TrueEager
# 438  1702042973951668628      Melissa_Lem
# 439  1702044083286397074   eyeonthearctic
# 440  1702215241457967315  Theresa70948126
# 441  1702362826260750342         CBCbrief
# 442  1702675827521917337       CabinRadio
#
#                                                   name  \
# 433                                           CBC News
# 434                                         News Funda
# 435                                The Weather Network
# 436                      CBCbrief - CBC News headlines
# 437  True North Eager Beaver Podcast (he/him/Mr Bea...
# 438                                    Dr. Melissa Lem
# 439                                 RCI-EyeOnTheArctic
# ...

# %% [markdown]
# ### checking and replacimg  Null value in location colum

# %%
df.isnull().sum()
# Out:
# tweet_id           0
# username           0
# name               0
# creation_date      0
# text               0
# location         103
# dtype: int64

# %%
df.isna()
# Out:
#      tweet_id  username   name  creation_date   text  location
# 0       False     False  False          False  False      True
# 1       False     False  False          False  False      True
# 2       False     False  False          False  False     False
# 3       False     False  False          False  False     False
# 4       False     False  False          False  False     False
# ..        ...       ...    ...            ...    ...       ...
# 438     False     False  False          False  False     False
# 439     False     False  False          False  False     False
# 440     False     False  False          False  False      True
# 441     False     False  False          False  False      True
# 442     False     False  False          False  False     False
#
# [443 rows x 6 columns]

# %%
df.fillna("Unknown city", inplace=True)

# %%
df.head(10)
# Out:
#               tweet_id        username                 name  \
# 0  1691623868409004062  porterfieldlol    ts'ǫǫ̀kołı̨ı̨ ✨
# 1  1691945051574993282  porterfieldlol    ts'ǫǫ̀kołı̨ı̨ ✨
# 2  1691612322496737746  OurYellowknife  City of Yellowknife
# 3  1691913973527134239  weathernetwork  The Weather Network
# 4  1691633128434028992         NWTFire             NWT Fire
# 5  1691711288592793641    khaleejtimes        Khaleej Times
# 6  1691812759300641270  weathernetwork  The Weather Network
# 7  1691923323960344793       CndNwayne            CNDNWayne
# 8  1691933887281164396   RylundJohnson       Rylund Johnson
# 9  1691732591781744776   MarloVanMarck  Marlo Van Marck 🌎🍄🐝
#
#                     creation_date  \
# 0  Wed Aug 16 01:32:13 +0000 2023
# 1  Wed Aug 16 22:48:29 +0000 2023
# 2  Wed Aug 16 00:46:20 +0000 2023
# 3  Wed Aug 16 20:45:00 +0000 2023
# 4  Wed Aug 16 02:09:01 +0000 2023
# 5  Wed Aug 16 07:19:36 +0000 2023
# 6  Wed Aug 16 14:02:48 +0000 2023
# ...

# %%
df.isna()
# Out:
#      tweet_id  username   name  creation_date   text  location
# 0       False     False  False          False  False     False
# 1       False     False  False          False  False     False
# 2       False     False  False          False  False     False
# 3       False     False  False          False  False     False
# 4       False     False  False          False  False     False
# ..        ...       ...    ...            ...    ...       ...
# 438     False     False  False          False  False     False
# 439     False     False  False          False  False     False
# 440     False     False  False          False  False     False
# 441     False     False  False          False  False     False
# 442     False     False  False          False  False     False
#
# [443 rows x 6 columns]

# %% [markdown]
# #### checkin Data -type in the colum

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tweet_id       443 non-null    int64
#  1   username       443 non-null    object
#  2   name           443 non-null    object
#  3   creation_date  443 non-null    object
#  4   text           443 non-null    object
#  5   location       443 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 20.9+ KB

# %%
df
# Out:
#                 tweet_id         username                           name  \
# 0    1691623868409004062   porterfieldlol              ts'ǫǫ̀kołı̨ı̨ ✨
# 1    1691945051574993282   porterfieldlol              ts'ǫǫ̀kołı̨ı̨ ✨
# 2    1691612322496737746   OurYellowknife            City of Yellowknife
# 3    1691913973527134239   weathernetwork            The Weather Network
# 4    1691633128434028992          NWTFire                       NWT Fire
# ..                   ...              ...                            ...
# 438  1702042973951668628      Melissa_Lem                Dr. Melissa Lem
# 439  1702044083286397074   eyeonthearctic             RCI-EyeOnTheArctic
# 440  1702215241457967315  Theresa70948126               Theresa Robinson
# 441  1702362826260750342         CBCbrief  CBCbrief - CBC News headlines
# 442  1702675827521917337       CabinRadio                    Cabin Radio
#
#                       creation_date  \
# 0    Wed Aug 16 01:32:13 +0000 2023
# ...

# %% [markdown]
# #### converting creation_date to date Dtypes

# %%
df['creation_date'] = pd.to_datetime(df['creation_date'])

# %%
df.head()
# Out:
#               tweet_id        username                 name  \
# 0  1691623868409004062  porterfieldlol    ts'ǫǫ̀kołı̨ı̨ ✨
# 1  1691945051574993282  porterfieldlol    ts'ǫǫ̀kołı̨ı̨ ✨
# 2  1691612322496737746  OurYellowknife  City of Yellowknife
# 3  1691913973527134239  weathernetwork  The Weather Network
# 4  1691633128434028992         NWTFire             NWT Fire
#
#               creation_date  \
# 0 2023-08-16 01:32:13+00:00
# 1 2023-08-16 22:48:29+00:00
# 2 2023-08-16 00:46:20+00:00
# 3 2023-08-16 20:45:00+00:00
# 4 2023-08-16 02:09:01+00:00
#
#                                                 text  \
# 0  parts of Yellowknife are now on evacuation ale...
# 1  people are evacuating en-masse from Yellowknif...
# 2  The City is issuing an Evacuation Alert for so...
# 3  Wildfires turn the sky orange in #Yellowknife,...
# 4  (3/4)Fire has come within 20km of Yellowknife,...
#
#                     location
# 0               Unknown city
# 1               Unknown city
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tweet_id       443 non-null    int64
#  1   username       443 non-null    object
#  2   name           443 non-null    object
#  3   creation_date  443 non-null    datetime64[ns, UTC]
#  4   text           443 non-null    object
#  5   location       443 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(1), object(4)
# memory usage: 20.9+ KB

# %% [markdown]
# #### splitting the creation date column into creation date and creation  time columnn

# %%
#Split datetime column into 'creation_date' and 'creation_time'
#df['creation_date'] = df['creation_date'].dt.date
#df['creation_time'] = df['creation_date'].dt.time

# Display the resulting DataFrame
#print(df)

# %%
#df['creation_date'] = df['creation_date'].dt.strftime('%Y-%m-%d')
#df['creation_time'] = df['creation_date'].dt.strftime('%H:%M:%S')

# %%
df
# Out:
#                 tweet_id         username                           name  \
# 0    1691623868409004062   porterfieldlol              ts'ǫǫ̀kołı̨ı̨ ✨
# 1    1691945051574993282   porterfieldlol              ts'ǫǫ̀kołı̨ı̨ ✨
# 2    1691612322496737746   OurYellowknife            City of Yellowknife
# 3    1691913973527134239   weathernetwork            The Weather Network
# 4    1691633128434028992          NWTFire                       NWT Fire
# ..                   ...              ...                            ...
# 438  1702042973951668628      Melissa_Lem                Dr. Melissa Lem
# 439  1702044083286397074   eyeonthearctic             RCI-EyeOnTheArctic
# 440  1702215241457967315  Theresa70948126               Theresa Robinson
# 441  1702362826260750342         CBCbrief  CBCbrief - CBC News headlines
# 442  1702675827521917337       CabinRadio                    Cabin Radio
#
#                 creation_date  \
# 0   2023-08-16 01:32:13+00:00
# ...

# %%
df.columns
# Out:
# Index(['tweet_id', 'username', 'name', 'creation_date', 'text', 'location'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tweet_id       443 non-null    int64
#  1   username       443 non-null    object
#  2   name           443 non-null    object
#  3   creation_date  443 non-null    datetime64[ns, UTC]
#  4   text           443 non-null    object
#  5   location       443 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(1), object(4)
# memory usage: 20.9+ KB

# %%
df['creation_date'] = pd.to_datetime(df['creation_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tweet_id       443 non-null    int64
#  1   username       443 non-null    object
#  2   name           443 non-null    object
#  3   creation_date  443 non-null    datetime64[ns, UTC]
#  4   text           443 non-null    object
#  5   location       443 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(1), object(4)
# memory usage: 20.9+ KB

# %%
df
# Out:
#                 tweet_id         username                           name  \
# 0    1691623868409004062   porterfieldlol              ts'ǫǫ̀kołı̨ı̨ ✨
# 1    1691945051574993282   porterfieldlol              ts'ǫǫ̀kołı̨ı̨ ✨
# 2    1691612322496737746   OurYellowknife            City of Yellowknife
# 3    1691913973527134239   weathernetwork            The Weather Network
# 4    1691633128434028992          NWTFire                       NWT Fire
# ..                   ...              ...                            ...
# 438  1702042973951668628      Melissa_Lem                Dr. Melissa Lem
# 439  1702044083286397074   eyeonthearctic             RCI-EyeOnTheArctic
# 440  1702215241457967315  Theresa70948126               Theresa Robinson
# 441  1702362826260750342         CBCbrief  CBCbrief - CBC News headlines
# 442  1702675827521917337       CabinRadio                    Cabin Radio
#
#                 creation_date  \
# 0   2023-08-16 01:32:13+00:00
# ...

# %% [markdown]
# ### ### 1. How are different groups in the city affected by the evacuation?

# %%
#Analyze by Location
location_impact = df.groupby('location')['tweet_id'].count()

# Analyze by Usernames
username_impact = df.groupby('username')['tweet_id'].count()

# Analyze by Text Content (Example: Identify tweets mentioning specific keywords)
keyword = 'evacuation'
keyword_tweets = df[df['text'].str.contains(keyword, case=False, na=False)]

# Analyze over Time
time_impact = df.set_index('creation_date').resample('D')['tweet_id'].count()

# Display the results or further analyze as needed
print("Impact by Location:")
print(location_impact)

print("\nImpact by Usernames:")
print(username_impact)

print("\nTweets mentioning '{}'".format(keyword))
print(keyword_tweets[['username', 'text']])

print("\nImpact over Time:")
print(time_impact)
#Feel free to adapt this example to suit your specific analysis goals and explore additional features in your dataset that might provide insights into how different groups are affected by the evacuation.
# Out:
# Impact by Location:
# location
# 13376 Comber Way Surrey BC        1
# 365 Bloor St. E., Toronto, ON     1
# 39 4th Street NE Calgary Ab       1
# 4700 Keele St, Toronto, Canada    1
# 49% Nepal, 26% Canada, 25% USA    1
#                                  ..
# brora, famedforhintersofbrora     1
# new york                          1
# nfb                               1
# williams lake                     1
# 🇨🇦                                2
# Name: tweet_id, Length: 160, dtype: int64
#
# Impact by Usernames:
# username
# 20xt6             1
# 610CKTB           1
# 6ixbuzztv         1
# ABCommunist       1
# ACStefanoM        1
#                  ..
# weathernetwork    3
# winsyyc           1
# womenscentre      1
# wranglindogs      2
# yara_tess         1
# Name: tweet_id, Length: 285, dtype: int64
#
# Tweets mentioning 'evacuation'
#             username                                               text
# 0     porterfieldlol  parts of Yellowknife are now on evacuation ale...
# ...

# %%
pip install nltk wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
pip install Pillow
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)

# %%
pip install --upgrade Pillow
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)

# %%
pip install --upgrade Pillow == 9.2.0
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# ERROR: Invalid requirement: '=='
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\hp\anaconda3.1\lib\site-packages)

# %% [markdown]
# ### Using Worldclouds : It creates word clouds, which are graphical representations of
#     word frequency in a given set of text data. In a word cloud, more frequent words are displayed larger and bolder.

# %%
from wordcloud import WordCloud
from PIL import Image
import pandas as pd
import matplotlib.pyplot as plt
from nltk.sentiment import SentimentIntensityAnalyzer

# Perform Sentiment Analysis
def analyze_sentiment(text):
    sia = SentimentIntensityAnalyzer()
    sentiment_score = sia.polarity_scores(text)['compound']
    if sentiment_score >= 0.05:
        return 'Positive'
    elif sentiment_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# Apply sentiment analysis to each tweet
df['sentiment'] = df['text'].apply(analyze_sentiment)

# Visualize Sentiment Distribution
sentiment_distribution = df['sentiment'].value_counts()
sentiment_distribution.plot(kind='bar', color=['green', 'red', 'yellow'])
plt.title('Sentiment Distribution on Evacuation Tweets')
plt.xlabel('Sentiment')
plt.ylabel('Number of Tweets')
plt.show()

# Create Word Cloud for Positive and Negative Sentiments
positive_tweets = ' '.join(df[df['sentiment'] == 'Positive']['text'])
negative_tweets = ' '.join(df[df['sentiment'] == 'Negative']['text'])

# Generate Word Cloud for Positive Sentiment
wordcloud_positive = WordCloud(width=800, height=400, background_color='white', font_path='C:/Windows/Fonts/Arial.ttf').generate(positive_tweets)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_positive, interpolation='bilinear')
plt.title('Word Cloud for Positive Sentiment')
plt.axis('off')
plt.show()

# Generate Word Cloud for Negative Sentiment
wordcloud_negative = WordCloud(width=800, height=400, background_color='white', font_path='C:/Windows/Fonts/Arial.ttf').generate(negative_tweets)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_negative, interpolation='bilinear')
plt.title('Word Cloud for Negative Sentiment')
plt.axis('off')
plt.show()

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt



# Perform Sentiment Analysis
def analyze_sentiment(text):
    sia = SentimentIntensityAnalyzer()
    sentiment_score = sia.polarity_scores(text)['compound']
    if sentiment_score >= 0.05:
        return 'Positive'
    elif sentiment_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# Apply sentiment analysis to each tweet
df['sentiment'] = df['text'].apply(analyze_sentiment)

# Visualize Sentiment Distribution
sentiment_distribution = df['sentiment'].value_counts()
sentiment_distribution.plot(kind='bar', color=['green', 'red', 'yellow'])
plt.title('Sentiment Distribution on Evacuation Tweets')
plt.xlabel('Sentiment')
plt.ylabel('Number of Tweets')
plt.show()

# %% [markdown]
# #### Question: Checking for different group that can take care of themselves

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer


# Replace 'text_column' with the actual column name containing tweet text

# Perform Sentiment Analysis
def analyze_sentiment(text):
    sia = SentimentIntensityAnalyzer()
    sentiment_score = sia.polarity_scores(text)['compound']
    if sentiment_score >= 0.05:
        return 'Positive'
    elif sentiment_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# Apply sentiment analysis to each tweet
df['sentiment'] = df['text'].apply(analyze_sentiment)

# Identify groups that can take care of themselves based on sentiment
self_sufficient_groups = df[df['sentiment'] == 'Positive']

# Display the groups that can take care of themselves
print(self_sufficient_groups[['username', 'text']])
# Out:
#            username                                               text
# 0    porterfieldlol  parts of Yellowknife are now on evacuation ale...
# 1    porterfieldlol  people are evacuating en-masse from Yellowknif...
# 2    OurYellowknife  The City is issuing an Evacuation Alert for so...
# 4           NWTFire  (3/4)Fire has come within 20km of Yellowknife,...
# 7         CndNwayne  @ProfBillMcGuire Please no. Hay River is acros...
# ..              ...                                                ...
# 426        calmecam  🎙️True North Eager Beaver Interview Project🎙️\...
# 430       TrueEager  🎙️True North Eager Beaver Interview Project🎙️\...
# 431        calmecam  🎙️True North Eager Beaver Interview Project🎙️\...
# 432       LSpooner2  Our journey to return home started today. 27 d...
# 437       TrueEager  🎙️True North Eager Beaver Interview Project🎙️\...
#
# [150 rows x 2 columns]
